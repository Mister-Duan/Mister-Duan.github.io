# %% [markdown]
# # 基础

# %%
import pandas as pd
df=pd.read_csv('../datasets/titanic.csv')

# %%
# 显示多列
df[['Age','Fare']][:5]
# df
# Out:
#     Age     Fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
# 定位具体的某一个数据
# loc 用label来定位

# iloc 用position来去定位
df.iloc[0]
df.iloc[0:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[0:5,1:3]
# Out:
#    Survived  Pclass
# 0         0       3
# 1         1       1
# 2         1       3
# 3         1       1
# 4         0       3

# %%
df=df.set_index('Name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/f6/69sb2tws0_3_c9b0qzmw33gr0000gn/T/ipykernel_31451/2514733362.py in ?()
# ----> 1 df=df.set_index('Name')
#
# ~/Desktop/project/soft/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['Name'] are in the columns"

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
# 当用标签当索引的时候用loc
df.loc['Braund, Mr. Owen Harris']
# Out:
# PassengerId            1
# Survived               0
# Pclass                 3
# Sex                 male
# Age                 22.0
# SibSp                  1
# Parch                  0
# Ticket         A/5 21171
# Fare                7.25
# Cabin                NaN
# Embarked               S
# Name: Braund, Mr. Owen Harris, dtype: object

# %%
df.loc['Braund, Mr. Owen Harris':'Heikkinen, Miss. Laina']['Age']
# Out:
# Name
# Braund, Mr. Owen Harris                                22.0
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    38.0
# Heikkinen, Miss. Laina                                 26.0
# Name: Age, dtype: float64

# %%
# 修改数据
df.loc['Braund, Mr. Owen Harris','Fare']=99999

# %%
df['Fare'] > 40
# Out:
# Name
# Braund, Mr. Owen Harris                                 True
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)     True
# Heikkinen, Miss. Laina                                 False
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            True
# Allen, Mr. William Henry                               False
#                                                        ...
# Montvila, Rev. Juozas                                  False
# Graham, Miss. Margaret Edith                           False
# Johnston, Miss. Catherine Helen "Carrie"               False
# Behr, Mr. Karl Howell                                  False
# Dooley, Mr. Patrick                                    False
# Name: Fare, Length: 891, dtype: bool

# %%
df['Fare'] > 40 # 得到索引
df[df['Fare'] > 40] #将索引回传给DataIframe
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# McCarthy, Mr. Timothy J                                       7         0
# Fortune, Mr. Charles Alexander                               28         0
# ...                                                         ...       ...
# Wick, Mrs. George Dennick (Mary Hitchcock)                  857         1
# Sage, Miss. Dorothy Edith "Dolly"                           864         0
# Roebling, Mr. Washington Augustus II                        868         0
# Beckwith, Mrs. Richard Leonard (Sallie Monypeny)            872         1
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)               880         1
#
# ...

# %%
list=df[df['Fare'] > 40] #船费大于40
key=list['Age'] < 10  # 且年龄小于10
list[key]
# Out:
#                                           PassengerId  Survived  Pclass  \
# Name
# Laroche, Miss. Simonne Marie Anne Andree           44         1       2
# Allison, Miss. Helen Loraine                      298         0       1
# Allison, Master. Hudson Trevor                    306         1       1
# Goodwin, Master. Sidney Leonard                   387         0       3
# Dodge, Master. Washington                         446         1       1
# Goodwin, Master. Harold Victor                    481         0       3
#
#                                              Sex   Age  SibSp  Parch  \
# Name
# Laroche, Miss. Simonne Marie Anne Andree  female  3.00      1      2
# Allison, Miss. Helen Loraine              female  2.00      1      2
# Allison, Master. Hudson Trevor              male  0.92      1      2
# Goodwin, Master. Sidney Leonard             male  1.00      5      2
# Dodge, Master. Washington                   male  4.00      0      2
# ...

# %%
df.loc[df['Sex']=='male','Age'].mean()
# Out:
# 30.72664459161148

# %% [markdown]
# # 进阶

# %%
import pandas as pd
import numpy as np

s=pd.Series(np.arange(5),index=np.arange(5)[::-1],dtype='int64')
s
# Out:
# 4    0
# 3    1
# 2    2
# 1    3
# 0    4
# dtype: int64

# %%
# 看索引在不在其中
s.isin([1,3,4])
# Out:
# 4    False
# 3     True
# 2    False
# 1     True
# 0     True
# dtype: bool

# %%
s[s.isin([1,3,4])]
# Out:
# 3    1
# 1    3
# 0    4
# dtype: int64

# %%
s2 = pd.Series(np.arange(9),index=pd.MultiIndex.from_product([[0,1,2],['a','b','c']]))
s2
# Out:
# 0  a    0
#    b    1
#    c    2
# 1  a    3
#    b    4
#    c    5
# 2  a    6
#    b    7
#    c    8
# dtype: int64

# %%
s2.iloc[s2.index.isin([(1,'a'),(2,'b')])]
# Out:
# 1  a    3
# 2  b    7
# dtype: int64

# %%
s=pd.Series(np.arange(5),index=np.arange(5)[::-1])
s
# Out:
# 4    0
# 3    1
# 2    2
# 1    3
# 0    4
# dtype: int64

# %%
s[s>2]
# Out:
# 1    3
# 0    4
# dtype: int64

# %%
dates=pd.date_range('20171124',periods=8)
df=pd.DataFrame(np.random.randn(8,4),index=dates,columns=['A','B','C','D'])
df
# Out:
#                    A         B         C         D
# 2017-11-24  0.390431  0.502721 -0.413353 -1.629603
# 2017-11-25 -0.209553  0.538227 -0.981116 -0.659934
# 2017-11-26  0.824603 -1.177034  0.324129  0.363602
# 2017-11-27 -0.710240  0.499165  1.278330 -0.577166
# 2017-11-28 -0.149335  0.242615 -0.481670  0.852776
# 2017-11-29 -0.753882 -0.441465 -0.804489  0.842414
# 2017-11-30  1.408195  2.700727 -0.305393 -1.330566
# 2017-12-01  0.995723  0.927235 -0.975295  0.739456

# %%
# df.select(lambda x:x=='A',axis='colum')

# %%
df.where(df<0)
# Out:
#                    A         B         C         D
# 2017-11-24       NaN       NaN -0.413353 -1.629603
# 2017-11-25 -0.209553       NaN -0.981116 -0.659934
# 2017-11-26       NaN -1.177034       NaN       NaN
# 2017-11-27 -0.710240       NaN       NaN -0.577166
# 2017-11-28 -0.149335       NaN -0.481670       NaN
# 2017-11-29 -0.753882 -0.441465 -0.804489       NaN
# 2017-11-30       NaN       NaN -0.305393 -1.330566
# 2017-12-01       NaN       NaN -0.975295       NaN

# %%
df.where(df<0,-df)
# Out:
#                    A         B         C         D
# 2017-11-24 -0.390431 -0.502721 -0.413353 -1.629603
# 2017-11-25 -0.209553 -0.538227 -0.981116 -0.659934
# 2017-11-26 -0.824603 -1.177034 -0.324129 -0.363602
# 2017-11-27 -0.710240 -0.499165 -1.278330 -0.577166
# 2017-11-28 -0.149335 -0.242615 -0.481670 -0.852776
# 2017-11-29 -0.753882 -0.441465 -0.804489 -0.842414
# 2017-11-30 -1.408195 -2.700727 -0.305393 -1.330566
# 2017-12-01 -0.995723 -0.927235 -0.975295 -0.739456

# %%
df =  pd.DataFrame(np.random.rand(10,3),columns=['a','b','c'])
df
# Out:
#           a         b         c
# 0  0.228275  0.573241  0.593483
# 1  0.960843  0.762709  0.336328
# 2  0.809381  0.739125  0.767647
# 3  0.891682  0.096504  0.521340
# 4  0.210043  0.875651  0.410582
# 5  0.674458  0.229916  0.934268
# 6  0.553672  0.187054  0.534213
# 7  0.453802  0.211801  0.051366
# 8  0.735539  0.354813  0.697179
# 9  0.524405  0.434295  0.443096

# %%
df.query('(a<b) & (b<c)')
# Out:
#           a         b         c
# 0  0.228275  0.573241  0.593483
