# %% [markdown]
# - **全局**
#     - **药靶病企气泡**
#     - **TC权限拦截/引流开发 + NP/GO/Med-TC流量转化**
#     - **批量下载前端前置工作**
#     - **可视化样式交互升级(35+)**
#     - **视觉升级基础组件优化**
#     - 全局通知组件适配/布局组件梳理
#     - 注册性临床注释
#     - 引流埋点调整
#     - 可视化图表新增药企病靶悬浮气泡
#     - 可视化渲染优化
#     - 导出限制添加
#     - 错误日志排查并修复
#     - eslint
# - **全球临床**
#     - **CRO详情页开发**
#     - **试验对比信息重构**
#     - **时光轴优化**
#     - **左侧检索升级+表格二筛**
#     - 甘特图增加【图例说明】
#     - 全临主研参研合并检索
#     - 台湾数据源适配
#     - Med跳转登记号详情页的访问权限
#     - 招募效率调整
#     - 试验开展地区】增加全选功能按钮
#     - 全临-单/多靶点检索功能开发
#     - JRCT、KOR、RBR全量历史版本数据对比前端适配调整
#     - 前台展示登记平台公示结果
#     - 前台新增展示试验登记人联系信息
#     - 全临新增【药品最高研发阶段】
#     - 研究/登记号详情页-入排统一展开/收起
#     - 情报整合
#         - 支持获批的优化调整
#         - 简要结果展示优化
#         - 招募效率优化
#     - nct/study详情页联系人优化
#     - nct登记号模糊优化
#     - 前台【中国】统一调整为【中国内地】逻辑调整
#     - 无官网历史数据源【方案变更历史】展示
#     - 终点指标标准化字段检索+展示
#     - 前台【不再招募】统一调整为【完成招募】
#     - 生物标记物、分期、线程页面调整
#     - 全临列表字段展示优化
#     - 前台展示FIH标签
# - 研究中心/研究者
#     - **详情页改版**
#     - **详情页新增PDF下载功能**
#     - 基本信息/hpi纬度等样式/逻辑开发
#     - 详情页可视化穿透
#     - 机构备案监督检查信息展示
#     - 研究中心详情页新增【研究中心启动信息】
#     - 备案监督检查
#     - 研究中心启动信息/功能小优化
#     - 研究者/研究中心-申办方可视化图表优化
# - 注册性临床
#     - 增加支持获批研究相关字段

# %% [markdown]
# - NP
#     - 基础查询/并购/交易可视化可视化开发
#         - 改版可视化(8+18)（+许宁 +杨康）
#             - 负责12可视化(4张自定义的可视化)
#             - 负责整体的组件模版开发以及部分难点支持
#         - NP->TC引流气泡开发
# - 案例中心组件更新/vite/pnpm等构建工具调整/代码优化
# - npm仓库源依赖服务配合升级
# - 防爬加强接入支持（webpack5/vite开发）
# - 截屏日志文件按时间/大小分割
# - 截屏支持防爬调整
# - 药靶病企通用气泡组件的提取(np/med)
# - 可视化组件支持批量下载开发/文档维护
# - 新版本可视化组件升级
# - PI构建问题排查支持
# - 构建内存降低优化调整，防止服务因构建死机
# - 跨项目跳转组件开发
# - 导出流程组件开发
# - TC的性能指标分析
# - MA 支持
#     - 精选公告模块开发 已上线
#     - 催化剂订阅推送功能 等接口数据联调
# - 共创项目-前端监控
#     - 脚本构建（rollup+monorepo+ts）搭建
#     - 错误收集与stack/sourceMap解析/数据格式归一
# - 个人技术
#     - upload 支持map隔离上传
#     - 登记号详情页大文件pdf生成需求调研
#     - 可视化图表新增药企病靶悬浮气泡调研
#     - 组件整理/迁移案例中心分享
